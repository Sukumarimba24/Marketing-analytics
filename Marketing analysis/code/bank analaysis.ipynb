# %% [markdown]
# #**DSM-I Assignment I**
# Use "bank-additional-full.csv" dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##### Load Data & Create a colunmn "conversion" by refering the column "y"

# %%
df = pd.read_csv("bank-additional-full.csv", sep=';')

# %%
df['conversion'] = df['y'].apply(lambda x:1 if x=='yes'else 0)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  conversion
# ...

# %% [markdown]
# ###**Aggregate conversion rate tellsthe overall performance of Marketing Campaigns**
#
# ##### 1. Break down the customer base into multiple segments according to Education  ***Hint: Use Pivot table***

# %%
conversions_by_education_df =pd.pivot_table(df, values='y', index='education',  columns='conversion',aggfunc=len)
conversions_by_education_df
# Out:
# conversion               0     1
# education
# basic.4y              3748   428
# basic.6y              2104   188
# basic.9y              5572   473
# high.school           8484  1031
# illiterate              14     4
# professional.course   4648   595
# university.degree    10498  1670
# unknown               1480   251

# %%
conversions_by_education_df.columns =['non_conversions', 'conversions']
conversions_by_education_df
# Out:
#                      non_conversions  conversions
# education
# basic.4y                        3748          428
# basic.6y                        2104          188
# basic.9y                        5572          473
# high.school                     8484         1031
# illiterate                        14            4
# professional.course             4648          595
# university.degree              10498         1670
# unknown                         1480          251

# %% [markdown]
# ##### **2. To visualize, use pie-chart for each group**

# %%
labels = ['basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown']
non_conversions = [3748,2104,5572,8484,14,4648,10498,1480]
conversions = [428,188,473,1031,4,595,1670,251]

# Non-conversions pie
plt.pie(non_conversions, labels=labels, autopct='%1.1f%%',startangle=90)
plt.title('Non Conversions')
plt.show()

# Conversions pie
plt.pie(conversions, labels=labels, autopct='%1.1f%%',startangle=90)
plt.title('Conversions')
plt.show()

plt.show()

# %% [markdown]
# #####**3. Break down the customer base into multiple segments according to Job  ** *Hint : Use Pivot table*

# %%
conversions_by_job_df =pd.pivot_table(df, values='y', index='job',  columns='conversion',aggfunc=len)
conversions_by_job_df
# Out:
# conversion        0     1
# job
# admin.         9070  1352
# blue-collar    8616   638
# entrepreneur   1332   124
# housemaid       954   106
# management     2596   328
# retired        1286   434
# self-employed  1272   149
# services       3646   323
# student         600   275
# technician     6013   730
# unemployed      870   144
# unknown         293    37

# %%
conversions_by_job_df.columns =['non_conversions', 'conversions']
conversions_by_job_df
# Out:
#                non_conversions  conversions
# job
# admin.                    9070         1352
# blue-collar               8616          638
# entrepreneur              1332          124
# housemaid                  954          106
# management                2596          328
# retired                   1286          434
# self-employed             1272          149
# services                  3646          323
# student                    600          275
# technician                6013          730
# unemployed                 870          144
# unknown                    293           37

# %% [markdown]
# ##### **4. To visualize, use pie-chart for each group**

# %%
labels = ['admin','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown']
non_conversions = [9070,8616,1332,954,2596,1286,1272,3646,600,6013,870,293	]
conversions = [1352,638,124,106,328,434,149,323,275,730,144,37]

# Non-conversions pie
plt.pie(non_conversions, labels=labels, autopct='%1.1f%%',startangle=90)
plt.title('Non Conversions')
plt.show()

# Conversions pie
plt.pie(conversions, labels=labels, autopct='%1.1f%%',startangle=90)
plt.title('Conversions')
plt.show()

plt.show()


plt.show()

# %% [markdown]
# **Load Advertising data**

# %%
df1 = pd.read_csv("Advertising.csv", index_col = 'Date')
df1.head()
# Out:
#            Products     Web  Newspaper  Radio     TV
# Date
# 01/01/2018   Mobile  230100      69200  37800  22100
# 01/02/2018   Mobile   44500      45100  39300  10400
# 01/03/2018   Mobile   17200      69300  45900   9300
# 01/04/2018   Mobile  151500      58500  41300  18500
# 01/05/2018   Mobile  180800      58400  10800  12900

# %% [markdown]
# **5. Identify the count of each product**

# %%
df1['Products'].unique()
# Out:
# array(['Mobile', 'Electronics', 'Laptops'], dtype=object)

# %%
df1['Products'].value_counts()
# Out:
# Products
# Mobile         129
# Electronics     53
# Laptops         18
# Name: count, dtype: int64

# %% [markdown]
# ##### **6.Display media wise product count**

# %%
df1.groupby('Products')[['Newspaper','Web','TV','Radio']].count()
# Out:
#              Newspaper  Web   TV  Radio
# Products
# Electronics         53   53   53     53
# Laptops             18   18   18     18
# Mobile             129  129  129    129
